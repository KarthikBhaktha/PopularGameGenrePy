# %% [markdown]
# # To find the leading genre of games that was launched from a dataset contiaining data gathered from 2006 to 2016.
# ## To do:
# - Check which genre was developed most frequently by developers (Use Histogram)
# - See which platform developed the most frequent genre (Use bar chart)
# - Which platform got the highest score for which genre (Find a relationship between genre and platform)

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotting import *
sns.set_style('whitegrid')
sns.set(font_scale=1)
# %matplotlib inline

# %%
#importing ign review csv file
df = pd.read_csv('ign.csv', header=0, index_col=0)
df.index+=1
df.head(10)
# Out:
#    score_phrase                                              title  \
# 1       Amazing                            LittleBigPlanet PS Vita
# 2       Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 3         Great                               Splice: Tree of Life
# 4         Great                                             NHL 13
# 5         Great                                             NHL 13
# 6          Good                          Total War Battles: Shogun
# 7         Awful                                Double Dragon: Neon
# 8       Amazing                                       Guild Wars 2
# 9         Awful                                Double Dragon: Neon
# 10         Good                          Total War Battles: Shogun
#
#                                                   url          platform  \
# 1              /games/littlebigplanet-vita/vita-98907  PlayStation Vita
# 2   /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita
# 3                           /games/splice/ipad-141070              iPad
# 4                       /games/nhl-13/xbox-360-128182          Xbox 360
# 5                            /games/nhl-13/ps3-128181     PlayStation 3
# 6          /games/total-war-battles-shogun/mac-142565         Macintosh
# 7           /games/double-dragon-neon/xbox-360-131320          Xbox 360
# 8                       /games/guild-wars-2/pc-896298                PC
# 9                /games/double-dragon-neon/ps3-131321     PlayStation 3
# 10          /games/total-war-battles-shogun/pc-142564                PC
#
#     score       genre editors_choice  release_year  release_month  release_day
# 1     9.0  Platformer              Y          2012              9           12
# 2     9.0  Platformer              Y          2012              9           12
# 3     8.5      Puzzle              N          2012              9           12
# 4     8.5      Sports              N          2012              9           11
# 5     8.5      Sports              N          2012              9           11
# 6     7.0    Strategy              N          2012              9           11
# 7     3.0    Fighting              N          2012              9           11
# 8     9.0         RPG              Y          2012              9           11
# 9     3.0    Fighting              N          2012              9           11
# 10    7.0    Strategy              N          2012              9           11

# %%
df.head(50)
sort_by_year = df.sort_values(['release_year','platform','genre'])
type(sort_by_year)
# Out:
# pandas.core.frame.DataFrame

# %%
sort_by_year.head()
# Out:
#     score_phrase                                              title  \
# 517        Great  The Walking Dead: The Game -- Episode 1: A New...
# 589         Okay                   Star Wars: Shadows of the Empire
# 484          Bad                              Mortal Kombat Trilogy
# 591         Okay                               Killer Instinct Gold
# 489        Great                                      Pilotwings 64
#
#                                                    url     platform  score  \
# 517  /games/the-walking-dead-season-1-episode-1/xbo...     Xbox 360    8.5
# 589     /games/star-wars-shadows-of-the-empire/n64-415  Nintendo 64    6.5
# 484               /games/mortal-kombat-trilogy/n64-454  Nintendo 64    4.1
# 591                /games/killer-instinct-gold/n64-499  Nintendo 64    6.5
# 489                        /games/pilotwings-64/n64-83  Nintendo 64    8.2
#
#          genre editors_choice  release_year  release_month  release_day
# 517  Adventure              N          1970              1            1
# 589     Action              N          1996             12            9
# 484   Fighting              N          1996             11           20
# 591   Fighting              N          1996             12            4
# 489     Flight              N          1996              9           25

# %%
sort_by_year.score = sort_by_year.score.astype(int)
sort_by_year.tail(10)
# Out:
#       score_phrase                                     title  \
# 18572      Amazing                                 Overwatch
# 18603         Good                         Hitman: Episode 4
# 18612     Mediocre  Tom Clancy's The Division -- Underground
# 18598          Bad                             7 Days to Die
# 18387        Great                             Rocket League
# 18453        Great                                   FIFA 17
# 18465      Amazing                 Pro Evolution Soccer 2017
# 18469        Great                                    NHL 17
# 18608         Good                                Pokemon Go
# 18420     Mediocre             Rick and Morty: Pocket Mortys
#
#                                                      url  platform  score  \
# 18572                 /games/overwatch/xbox-one-20045579  Xbox One      9
# 18603          /games/hitman-episode-4/xbox-one-20051639  Xbox One      7
# 18612  /games/tom-clancys-the-division-underground/xb...  Xbox One      5
# 18598             /games/7-days-to-die/xbox-one-20051934  Xbox One      4
# 18387             /games/rocket-league/xbox-one-20046670  Xbox One      8
# 18453                 /games/fifa-2017/xbox-one-20052734  Xbox One      8
# 18465  /games/pro-evolution-soccer-2017/xbox-one-2005...  Xbox One      9
# 18469                    /games/nhl-17/xbox-one-20052732  Xbox One      8
# 18608                  /games/pokemon-go/iphone-20042699    iPhone      7
# 18420  /games/rick-and-morty-pocket-mortys/iphone-200...    iPhone      5
#
#                     genre editors_choice  release_year  release_month  \
# 18572             Shooter              Y          2016              5
# 18603             Shooter              N          2016              8
# 18612             Shooter              N          2016              7
# 18598  Shooter, Adventure              N          2016              7
# 18387              Sports              N          2016              2
# 18453              Sports              N          2016              9
# 18465              Sports              Y          2016              9
# 18469              Sports              N          2016              9
# 18608              Battle              N          2016              7
# 18420                 RPG              N          2016              1
#
#        release_day
# 18572           28
# 18603           19
# 18612            6
# 18598           13
# 18387           23
# 18453           22
# 18465           13
# 18469           12
# 18608           13
# 18420           12

# %%
genre_score_year = sort_by_year[['genre','score','release_year']]
genre_score_year = pd.DataFrame(genre_score_year)
genre_score_year.head()
# Out:
#          genre  score  release_year
# 517  Adventure      8          1970
# 589     Action      6          1996
# 484   Fighting      4          1996
# 591   Fighting      6          1996
# 489     Flight      8          1996

# %%
sort_by_year.drop('editors_choice',axis=1,inplace=True)

# %%
sort_by_year.drop(sort_by_year.index[0],inplace=True)
sort_by_year.reset_index(drop = True).tail(10)
# Out:
#       score_phrase                                     title  \
# 18614      Amazing                                 Overwatch
# 18615         Good                         Hitman: Episode 4
# 18616     Mediocre  Tom Clancy's The Division -- Underground
# 18617          Bad                             7 Days to Die
# 18618        Great                             Rocket League
# 18619        Great                                   FIFA 17
# 18620      Amazing                 Pro Evolution Soccer 2017
# 18621        Great                                    NHL 17
# 18622         Good                                Pokemon Go
# 18623     Mediocre             Rick and Morty: Pocket Mortys
#
#                                                      url  platform  score  \
# 18614                 /games/overwatch/xbox-one-20045579  Xbox One      9
# 18615          /games/hitman-episode-4/xbox-one-20051639  Xbox One      7
# 18616  /games/tom-clancys-the-division-underground/xb...  Xbox One      5
# 18617             /games/7-days-to-die/xbox-one-20051934  Xbox One      4
# 18618             /games/rocket-league/xbox-one-20046670  Xbox One      8
# 18619                 /games/fifa-2017/xbox-one-20052734  Xbox One      8
# 18620  /games/pro-evolution-soccer-2017/xbox-one-2005...  Xbox One      9
# 18621                    /games/nhl-17/xbox-one-20052732  Xbox One      8
# 18622                  /games/pokemon-go/iphone-20042699    iPhone      7
# 18623  /games/rick-and-morty-pocket-mortys/iphone-200...    iPhone      5
#
#                     genre  release_year  release_month  release_day
# 18614             Shooter          2016              5           28
# 18615             Shooter          2016              8           19
# 18616             Shooter          2016              7            6
# 18617  Shooter, Adventure          2016              7           13
# 18618              Sports          2016              2           23
# 18619              Sports          2016              9           22
# 18620              Sports          2016              9           13
# 18621              Sports          2016              9           12
# 18622              Battle          2016              7           13
# 18623                 RPG          2016              1           12

# %%
sort_by_year.drop(sort_by_year.index[0],axis=0,inplace=True)

# %%
sort_by_year.isnull().any()
sort_by_year.describe()
# Out:
#               score  release_year  release_month   release_day
# count  18623.000000  18623.000000   18623.000000  18623.000000
# mean       6.627718   2006.517854       7.138538     15.605005
# std        1.702342      4.579316       3.476424      8.689801
# min        0.000000   1996.000000       1.000000      1.000000
# 25%        6.000000   2003.000000       4.000000      8.000000
# 50%        7.000000   2007.000000       8.000000     16.000000
# 75%        8.000000   2010.000000      10.000000     23.000000
# max       10.000000   2016.000000      12.000000     31.000000

# %%
sort_by_year.dropna(inplace=True)
sort_by_year.describe()
# Out:
#               score  release_year  release_month   release_day
# count  18587.000000  18587.000000   18587.000000  18587.000000
# mean       6.627804   2006.511164       7.139937     15.602572
# std        1.702650      4.580464       3.476760      8.692133
# min        0.000000   1996.000000       1.000000      1.000000
# 25%        6.000000   2003.000000       4.000000      8.000000
# 50%        7.000000   2007.000000       8.000000     16.000000
# 75%        8.000000   2010.000000      10.000000     23.000000
# max       10.000000   2016.000000      12.000000     31.000000

# %%
list_genre = sort_by_year['genre'].unique().tolist()

# %%
print(len(list_genre))
print(list_genre)
# Out:
# 112
# ['Fighting', 'Flight', 'Platformer', 'Racing', 'Sports', 'Action', 'Action, Adventure', 'Action, Compilation', 'Adventure', 'Compilation', 'Flight, Action', 'Puzzle', 'RPG', 'Racing, Action', 'Shooter', 'Simulation', 'Strategy', 'Wrestling', 'Action, RPG', 'Casino', 'Fighting, Compilation', 'Hunting', 'Music', 'Pinball', 'Puzzle, Action', 'Sports, Action', 'Battle', 'Board', 'Sports, Racing', 'Action, Simulation', 'Flight, Simulation', 'Sports, Simulation', 'Trivia', 'Music, Action', 'Strategy, RPG', 'Fighting, Action', 'Other', 'Party', 'Action, Platformer', 'Puzzle, Adventure', 'Educational, Puzzle', 'Productivity', 'Virtual Pet', 'Racing, Simulation', 'Card, Battle', 'Sports, Editor', 'Music, Editor', 'RPG, Editor', 'Educational, Action', 'Card', 'Card, RPG', 'Fighting, Adventure', 'Wrestling, Simulation', 'RPG, Compilation', 'RPG, Simulation', 'Flight, Racing', 'Sports, Compilation', 'Shooter, Platformer', 'Hunting, Simulation', 'Fighting, RPG', 'Pinball, Compilation', 'Card, Compilation', 'Racing, Compilation', 'Racing, Editor', 'Racing, Shooter', 'Other, Action', 'Puzzle, Compilation', 'Adult, Card', 'Educational', 'Educational, Productivity', 'Educational, Simulation', 'Educational, Trivia', 'Compilation, Compilation', 'Board, Compilation', 'Platformer, Action', 'Action, Editor', 'Hunting, Action', 'Puzzle, Word Game', 'Adventure, Compilation', 'Educational, Card', 'Educational, Adventure', 'Strategy, Compilation', 'Music, Compilation', 'Fighting, Simulation', 'Platformer, Adventure', 'Shooter, RPG', 'Other, Adventure', 'Simulation, Adventure', 'Adventure, Episodic', 'Adventure, Adult', 'Adventure, Platformer', 'Action, Puzzle', 'Sports, Fighting', 'Puzzle, RPG', 'Music, RPG', 'Adventure, Adventure', 'Adventure, RPG', 'Productivity, Action', 'RPG, Action', 'Shooter, First-Person', 'Baseball', 'Compilation, RPG', 'Sports, Baseball', 'Sports, Other', 'Sports, Party', 'Puzzle, Platformer', 'Action, Strategy', 'Music, Adventure', 'Strategy, Simulation', 'Sports, Golf', 'Hardware', 'Shooter, Adventure']

# %%
replace_genre = {'Action':'Action', 'Action, Adventure':'Action', 'Action, Compilation':'Action', 'Action, Platformer':'Action', 'Action, RPG':'RPG',
                 'Action, Simulation':'Simulation', 'Adventure':'Adventure','Battle':'Action', 'Board':'Strategy', 'Card':'Strategy', 'Card, Battle':'Strategy', 
                 'Card, RPG':'RPG', 'Casino':'Other', 'Compilation':'Other', 'Educational, Action':'Other','Educational, Puzzle':'Strategy',
                 'Fighting':'Action', 'Fighting, Action':'Action', 'Fighting, Adventure':'Adventure', 'Fighting, Compilation':'Action', 'Flight':'Adventure',
                 'Flight,Action':'Action', 'Flight, Racing':'Sports', 'Flight, Simulation':'Simulation', 'Hunting':'Sports', 'Music':'Other', 'Music, Action':'Action',
                 'Music, Editor':'Simulation', 'Other':'Other', 'Party':'Other', 'Pinball':'Sports', 'Platformer':'Other', 'Productivity':'Other', 'Puzzle':'Strategy',
                 'Puzzle, Action':'Strategy', 'Puzzle, Adventure':'Strategy', 'RPG':'RPG', 'RPG, Compilation':'RPG', 'RPG, Editor':'RPG', 'RPG, Simulation':'RPG', 'Racing':'Sports',
                 'Racing, Action':'Action', 'Racing, Simulation':'Simulation', 'Shooter':'Sports', 'Simulation':'Simulation', 'Sports':'Sports', 'Sports, Action':'Action',
                 'Sports, Compilation':'Sports', 'Sports, Editor':'Sports', 'Sports, Racing':'Sports', 'Sports, Simulation':'Simulation', 'Strategy':'Strategy', 'Strategy, RPG':'RPG', 
                 'Trivia':'Other', 'Virtual Pet':'Simulation', 'Wrestling':'Sports', 'Wrestling, Simulation':'Simulation', 'Action, Editor':'Action', 'Adult, Card':'Other',
                 'Board, Compilation':'Other', 'Card, Compilation':'Other', 'Compilation, Compilation':'Other', 'Educational':'Other', 'Educational, Productivity':'Other',
                 'Educational, Simulation':'Other', 'Educational, Trivia':'Strategy', 'Fighting, RPG':'RPG', 'Hunting, Action':'Action', 'Hunting, Simulation':'Simulation',
                 'Other, Action':'Action', 'Pinball, Compilation':'Other', 'Platformer, Action':'Action', 'Puzzle, Compilation':'Strategy', 'Racing, Compilation':'Sports',
                 'Racing, Editor':'Sports', 'Racing, Shooter':'Action', 'Shooter, Platformer':'Action', 'Puzzle, Word Game':'Other', 'Adventure, Compilation':'Action',
                 'Educational, Card':'Other', 'Educational, Adventure':'Other', 'Strategy, Compilation':'Strategy', 'Music, Compilation':'Other', 'Fighting, Simulation':'Simulation',
                 'Platformer, Adventure':'Simulation', 'Shooter, RPG':'RPG', 'Other, Adventure':'Other', 'Simulation, Adventure':'Simulation', 'Adventure, Episodic':'Simulation',
                 'Adventure, Adult':'Simulation', 'Adventure, Platformer':'Simulation', 'Action, Puzzle':'Other', 'Sports, Fighting':'Sports', 'Puzzle, RPG':'RPG', 'Music, RPG':'RPG',
                 'Adventure, Adventure':'Action', 'Adventure, RPG':'RPG', 'Productivity, Action':'Action', 'RPG, Action':'RPG', 'Shooter, First-Person':'Action',
                 'Baseball':'Sports', 'Compilation, RPG':'RPG', 'Sports, Baseball':'Sports', 'Sports, Other':'Sports', 'Sports, Party':'Sports', 'Puzzle, Platformer':'Other',
                 'Action, Strategy':'Strategy', 'Music, Adventure':'Other', 'Strategy, Simulation':'Strategy', 'Sports, Golf':'Sports', 'Hardware':'Other', 'Shooter, Adventure':'Action'}                                                                                          

genres = sort_by_year.genre.map(replace_genre)

# %%
df = pd.DataFrame(genres)

# %%
df.head()
# Out:
#          genre
# 484     Action
# 591     Action
# 489  Adventure
# 515      Other
# 485     Sports

# %%
sort_by_year['genre'] = df['genre']

# %%
sort_by_year.reset_index(inplace=True)

# %%
#deleting the unwanted columns
sort_by_year.drop(['index'], axis=1, inplace=True)
# sort_by_year.drop(['level_0'], axis=1, inplace=True)

# %%
sort_by_year.rename(columns={'release_year': 'release'}, inplace=True)
sort_by_year.head()
# Out:
#   score_phrase                  title                                   url  \
# 0          Bad  Mortal Kombat Trilogy  /games/mortal-kombat-trilogy/n64-454
# 1         Okay   Killer Instinct Gold   /games/killer-instinct-gold/n64-499
# 2        Great          Pilotwings 64           /games/pilotwings-64/n64-83
# 3      Amazing         Super Mario 64         /games/super-mario-64/n64-606
# 4      Amazing           Wave Race 64            /games/wave-race-64/n64-81
#
#       platform  score      genre  release  release_month  release_day
# 0  Nintendo 64      4     Action     1996             11           20
# 1  Nintendo 64      6     Action     1996             12            4
# 2  Nintendo 64      8  Adventure     1996              9           25
# 3  Nintendo 64      9      Other     1996              9           25
# 4  Nintendo 64      9     Sports     1996             11           15

# %%
grade_colors=['#f03b20',
             '#e34a33', 
             '#fde0dd', 
             '#fa9fb5', 
             '#c51b8a', 
             '#edf8b1', 
             '#7fcdbb', 
             '#2c7fb8', 
             '#a1d99b', 
             '#31a354', 
            ]
sns.set(color_codes = True)
sns.set_style('whitegrid')

# %%
sns.countplot(x = 'genre', data = sort_by_year, order = ['Action','Sports','Strategy','Other','RPG','Adventure','Simulation'] ,palette = grade_colors)
plt.title('Genre Distribution')
# Out:
# Text(0.5,1,'Genre Distribution')

# %%
sort_by_year.genre.value_counts().plot(kind='bar', figsize=(10,5))

# %% [markdown]
# ## Lets find out trends based on genres over the years.
# ### To find a trend in every genre over 20 years.

# %% [markdown]
# ## Finding a trend in Action genre from 1996 - 2016

# %% [markdown]
# ### Trend in Adventure genre

# %%
def trend(genre):
    action_g = sort_by_year.loc[sort_by_year['genre'] == genre]
    action_g.reset_index(inplace=True,drop=True)
    action_g.head()
    #group by year
    agb = pd.DataFrame({'count' : action_g.groupby( [ "release", "genre"] ).size()}).reset_index()
    ag = agb['count'].tolist()
    ry = agb['release'].tolist()
    sns.set(style="whitegrid")
    ax = sns.barplot(x=ry, y=ag)
    sns.despine()
    ax.set(xlabel='release', ylabel='count')
    return ax#plt.bar(ry,ag,) 
plt.rcParams['figure.figsize']=(10,5)

# %%
trend('Action')

# %%
trend('Strategy')

# %%
trend('Other')

# %%
trend('RPG')

# %%
trend('Adventure')

# %% [markdown]
# # Sales information
#
# ### Data Analysis to be performed over the gaming dataset:
# - Find Top gaming platforms most games developed for a platform
# - Top Gamming Genre
# - Year with most game releses
# - top performing gaming platform by year
# - Top performing gaming genre

# %%
# import the video game sales CSV in to pandas dataframe.
sales_df = pd.read_csv('video_game_sales.csv')
sales_df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
#changing the name of column Relase year.
sales_df.rename(columns={'Year_of_Release': 'Released'}, inplace=True)
sales_df.head()
# Out:
#                        Name Platform  Released         Genre Publisher  \
# 0                Wii Sports      Wii    2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES    1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii    2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii    2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB    1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
#cleaning the data
sales_df.dropna(how='any', subset=['Released','Name'],inplace = True)
sales_df[['Publisher','Developer','Rating']] = sales_df[['Publisher','Developer','Rating']].fillna('unknown')
sales_df[['Critic_Score','Critic_Count','User_Score','User_Count']] = sales_df[['Critic_Score','Critic_Count','User_Score','User_Count']].fillna(0)
# changing the release year data type to int
sales_df[['Released']] = sales_df[['Released']].astype(int, inplace = True)

# %%
sales_df.dtypes
# Out:
# Name             object
# Platform         object
# Released          int32
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# Critic_Score    float64
# Critic_Count    float64
# User_Score       object
# User_Count      float64
# Developer        object
# Rating           object
# dtype: object

# %%
sort_by_year['genre'].unique().tolist()
